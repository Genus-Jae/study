# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')
tips

sns.scatterplot(x = 'total_bill', y='tip', data = tips)
plt.title('Total Bill vs Tip')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 기본 데이터셋 로드
tips = sns.load_dataset('tips')

# 간단한 산점도 그리기
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title('Total Bill vs Tip')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np  # numpy 직접 가져오기

# 예제 데이터 생성
dates = pd.date_range('2026-01-01', periods=100)
prices = pd.Series(range(100)) + np.random.randn(100).cumsum()  # np.random으로 변경
stock_data = pd.DataFrame({'Date': dates, 'Price': prices})

stock_data
# Out:
#          Date       Price
# 0  2026-01-01   -1.329637
# 1  2026-01-02    0.497280
# 2  2026-01-03    3.052637
# 3  2026-01-04    3.345600
# 4  2026-01-05    4.551297
# ..        ...         ...
# 95 2026-04-06  108.520580
# 96 2026-04-07  108.672426
# 97 2026-04-08  108.374768
# 98 2026-04-09  108.758901
# 99 2026-04-10  109.024301
#
# [100 rows x 2 columns]

# %%
sns.lineplot(x = 'Date', y = 'Price', data = stock_data)
plt.title('Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터셋 로드
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#barplot의 기본동작 : mean() 인데 estimator = sum로 총합을 확인

sns.barplot(x = 'day', y = 'tip', data = tips, estimator = sum)

plt.title('Total Tips by Day')
plt.xlabel('Day of Week')
plt.ylabel('Total Tip Amount')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터셋 로드
tips = sns.load_dataset('tips')

sns.histplot(tips['total_bill'], kde = True, bins = 20)
plt.title('Distribution of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터셋 로드
tips = sns.load_dataset('tips')

sns.boxplot(x = 'sex', y = 'tip', data = tips)
plt.title('Distribution of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 바이올린 플롯 그리기
sns.violinplot(x='sex', y='tip', data=tips)
plt.title('Tip Amount by Sex')
plt.xlabel('Sex')
plt.ylabel('Tip Amount')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터셋 로드
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# 페어플롯 그리기
sns.pairplot(iris, hue='species')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터셋 로드
iris = sns.load_dataset('iris')

sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'time')
plt.title('Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()
