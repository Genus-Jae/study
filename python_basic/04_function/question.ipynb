# %% [markdown]
# 문제 1: 자기소개 하기
# "카피바라는 IT 회사 첫 출근 날, 자기소개를 준비했다."
# introduce()라는 함수를 만들어 "안녕하세요, 저는 카피바라 신입사원입니다!"라는 메시지를 출력하세요.
# 함수를 호출하여 카피바라의 자기소개를 출력하세요.

# %%
def introduce():
    print("안녕하세요, 저는 카피바라 신입사원입니다!")

introduce()
# Out:
# 안녕하세요, 저는 카피바라 신입사원입니다!

# %% [markdown]
# 문제 2: 출근 체크하기
# "카피바라는 출근할 때 출근부에 이름을 적어야 한다."
# check_in(name)이라는 함수를 만들어 매개변수 name을 입력받아 다음과 같이 출력하세요.
# "[이름]님, 출근 체크 완료!"
# 함수를 호출해 “카피바라"를 출근 체크하세요.

# %%
def check_in(name):
    print(name+'님, 출근 체크 완료!')

check_in('카피바라')
# Out:
# 카피바라님, 출근 체크 완료!

# %% [markdown]
# 문제 3: 업무 시간 계산하기
# "카피바라는 오늘 근무한 시간을 계산하고 싶다."
# work_hours(start, end)라는 함수를 만들어 매개변수 start(출근 시간)와 end(퇴근 시간)를 입력받아 근무 시간을 계산하세요.
# 근무 시간 = end - start
# 반환된 근무 시간을 출력하세요.
# 출력 예시: "오늘 근무한 시간은 [근무 시간]시간입니다."

# %%
def work_hours(start, end):
    time = end - start




start = int(input('출근시간?'))
end = int(input('퇴근 시간?'))   
print(f"오늘 근무한 시간은 {work_hpurs}시간입니다.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 9
#       5
#       6
#       7 start = int(input('출근시간?'))
#       8 end = int(input('퇴근 시간?'))
# ----> 9 print(f"오늘 근무한 시간은 {work_hpurs}시간입니다.")
#      10
#
# NameError: name 'work_hpurs' is not defined

# %% [markdown]
#  문제 4: 점심 메뉴 추천
# "점심시간, 카피바라는 팀원들에게 점심 메뉴를 추천해준다."
# recommend_menu(*menus)라는 함수를 만들어 여러 개의 점심 메뉴를 매개변수로 전달받으세요.
# 랜덤하게 하나의 메뉴를 선택하고 반환하세요.
# 출력 예시: "오늘의 점심 메뉴는 [선택된 메뉴]입니다!"
# 힌트: random.choice()를 사용하면 랜덤 선택이 가능합니다.

# %%
import random

def recommend_menu(*menus):

    lunch = random.choice(menus)
    return lunch
print(f'오늘의 점심 메뉴는 {recommend_menu('국밥','제육','돈가스')}입니다!')
# Out:
# 오늘의 점심 메뉴는 국밥입니다!

# %% [markdown]
# 문제 5: 오후 커피 마시기
# "오후에 졸린 카피바라는 커피를 마시려고 한다."
# coffee_time()이라는 함수를 만들어 다음과 같은 문자열을 반환하세요.
# "오후 3시입니다. 커피 한 잔 하세요!"
# 반환된 문자열을 출력하세요.

# %%
def coffee_time():
    return "오후 3시입니다. 커피 한 잔 하세요!"
coffee_time()
# Out:
# '오후 3시입니다. 커피 한 잔 하세요!'

# %% [markdown]
# 문제 6: 업무 성과 분석하기
# "카피바라는 오늘의 업무 성과를 보고해야 한다."
# work_report(tasks_done)이라는 함수를 만들어 오늘 처리한 업무 수를 매개변수로 받으세요.
# 함수는 다음 두 값을 반환합니다.
# tasks_done: 처리한 업무 수
# status: 업무 성과 평가 (10개 이상: "우수", 5~9개: "보통", 4개 이하: "노력 필요")
# 반환된 값을 사용해 다음 메시지를 출력하세요.
# "오늘 처리한 업무는 [업무 수]개입니다. 성과 평가: [평가]"

# %%
def work_reports(tasks_done):

    status = ""

    if tasks_done >= 10:
        status = '우수'
    elif tasks_done <= 9 and tasks_done >= 5:
        status = '보통'
    else:
        status = '노력 필요'

    return tasks_done, status

tasks_done, status = work_reports(10)

print(f"오늘 처리한 업무는 {tasks_done}개입니다. 성과 평가: {status}")
# Out:
# 오늘 처리한 업무는 10개입니다. 성과 평가: 우수

# %% [markdown]
# "카피바라는 첫 월급을 계산하고 세금을 공제해야 한다."
# calculate_salary(base_salary, bonus)라는 함수를 만들어 기본 월급과 보너스를 매개변수로 받으세요.
# 총 월급을 계산하고, 세금은 총 월급의 10%로 공제하세요.
# 함수는 다음 두 값을 반환합니다.
# net_salary: 실수령액 (총 월급 - 세금)
# tax: 세금 공제액
# 반환된 값을 사용해 다음 메시지를 출력하세요.
# "세전 월급: [총 월급]원, 세금: [세금]원, 실수령액: [실수령액]원"

# %%
def calculate_salary(base_salary, bonus):
    total = base_salary + bonus
    tax = total * 0.1
    net_salary = total - tax

    return total, tax, net_salary

result = calculate_salary(100, 50)

print(f'세전 월급: {result[0]}원 세금: {result[1]}원, 실수령액:{result[2]}원"')
# Out:
# 세전 월급: 150원 세금: 15.0원, 실수령액:135.0원"
