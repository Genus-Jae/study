# %%
def basic_function():
    print("Hello World")

basic_function()    # Hello World
# Out:
# Hello World

# %%
def greeting(name, greet):
    print(name,';',greet)

greeting('카피바라','안녕하세요~')
# Out:
# 카피바라 ; 안녕하세요~

# %%
def plus(num1,num2):
    print(num1+num2)

plus(10,20)
# Out:
# 30

# %%
def basic_function():
    print("Hello World")

basic_function()    # Hello World
# Out:
# Hello World

# %%
def greeting(name, greet = '처음 뵘'):
    print(name, ";",greet)

greeting('카피바라','안녕하세요~')
print('--------')
greeting('카피바라')
# Out:
# 카피바라 ; 안녕하세요~
# --------
# 카피바라 ; 처음 뵘

# %%
def information(name, color):
      print(name + '의 최애 색상', color,  sep=' : ')

information('capybara', 'black')
# Out:
# capybara의 최애 색상 : black

# %%
information(color='black',name='capybara')
information('capybara',color = 'black')
# information(color = 'black','capyvara')
# information(name = 'capybara','black')
# Out:
# capybara의 최애 색상 : black
# capybara의 최애 색상 : black

# %%
def introduce(name):
    return f'안녕하세요 {name} 강사 인사드립니다.'

result = introduce('카피바라')
print(result)
# Out:
# 안녕하세요 카피바라 강사 인사드립니다.

# %%
def test():
    print("hello")

result = test()
print(result)   # None
# Out:
# hello
# None

# %%
def calc(a,b):
    return a+b, a-b

print(calc(2,3))
print(type(calc(2,3)))
# Out:
# (5, -1)
# <class 'tuple'>

# %%
plus, minus = calc(2,3)
print(f'plus는 {plus}, minus는 {minus}')
# Out:
# plus는 5, minus는 -1

# %%
def add_many(*args):
    result = 0

    for i in args:
        result = result + i

    return result

print(add_many(1,2,3,4,5))
# Out:
# 15

# %%
def show(*args):
    print(args)

show(1,2,3,'capybara')
# Out:
# (1, 2, 3, 'capybara')

# %%
def show_info(**kwargs):
    print(kwargs)

show_info(name='capybara', age = 60)
# Out:
# {'name': 'capybara', 'age': 60}

# %%
def sum(a,b,c):
    return a+b+c

numbers = [1,2,3]
#sum(numbers)    

print(sum(*numbers))
# Out:
# 6

# %%
lambda x: x+1
lambda x: x**2
lambda x: x[1]

lambda x:(x+1 if x > 0 else x-1)
# Out:
# <function __main__.<lambda>(x)>

# %%
add = lambda x, y: x + y
print(add(3,5))
# Out:
# 8

# %%
def add(x,y):
    return x + y

print(add(3,5))
# Out:
# 8

# %%
numbers = [1, 2, 3, 4, 5]
squared_numbers = map(lambda x: x**2, numbers)
print(list(squared_numbers))
# Out:
# [1, 4, 9, 16, 25]

# %%
numbers = [1,2,3,4,5,6]
even_numbers = filter(lambda x: x % 2 == 0, numbers)
print(list(even_numbers))
# Out:
# [2, 4, 6]

# %%
points = [(1,2), (3,1), (5,-1)]
sorted_points = sorted(points, key=lambda x:x[1] )
print(sorted_points)
# Out:
# [(5, -1), (3, 1), (1, 2)]

# %%
students = [
    {"name":"bear", "score":90},
    {"name":"tiger", "score":70},
    {"name":"rabbit", "score":85}
]

# 점수 기준 정렬
print(sorted(students, key=lambda x: x["score"]))
# Out:
# [{'name': 'tiger', 'score': 70}, {'name': 'rabbit', 'score': 85}, {'name': 'bear', 'score': 90}]

# %%
def f(x):
    x = 100

a = 10
f(a)
print(a)    # 10 #변경 불가능 int str tuple
# Out:
# 10

# %%
def f(x):
    x[0] = 100

a = [1, 2, 3]
f(a)
print(a)    # [100, 2, 3]
# Out:
# [100, 2, 3]
